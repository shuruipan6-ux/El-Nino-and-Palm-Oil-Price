# %% [markdown]
# # 00 — Data Feasibility Audit
#
# **Project status:** research design and data feasibility. No forecasting result is claimed in this notebook.
#
# This notebook answers one question before modeling begins: can climate, MPOB physical-supply data, and palm-oil prices be assembled into a point-in-time monthly dataset without look-ahead bias?

# %% [markdown]
# ## Feasibility gate
#
# The project does not proceed to modeling until all three source modules have usable histories, documented units, and defensible publication lags.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from src.data_audit import build_feasibility_matrix, load_source_registry

# %%
registry = load_source_registry(ROOT / 'config' / 'data_sources.json')
feasibility = build_feasibility_matrix(registry, ROOT / 'data' / 'raw')
feasibility

# %% [markdown]
# ## Required manual checks
#
# For each source, record:
#
# 1. exact download endpoint and file format;
# 2. first and last available month;
# 3. unit and geographic coverage;
# 4. missing observations and revisions;
# 5. source publication date or conservative usable lag;
# 6. redistribution permission;
# 7. whether the history contains enough distinct ENSO regimes.

# %%
required_checks = feasibility.assign(
    history_verified=False,
    unit_verified=False,
    release_timing_verified=False,
    redistribution_verified=False,
)
required_checks

# %% [markdown]
# ## Decision rule
#
# The next notebook should only be created after a real monthly table can be produced and all fields marked `to_verify` have been resolved or conservatively lagged.
